# %%
import sys
sys.path.append('../..')
from consecution import Node, Pipeline, GlobalState, Clock
from collections import namedtuple, defaultdict
import datetime
from dateutil.parser import parse
import glob
import csv
import itertools
from __future__ import print_function

# %% [markdown]
# # Simple Linear Pipeline

# %%
class N(Node):
    def process(self, rec):
        print('{:<16} processing {}'.format(self, rec))
        self.push(rec)
        
one = N('one')
two = N('two')
three = N('tree')

one.add_downstream(two)
two.add_downstream(three)
pipe = Pipeline(one)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
#  one | two
#  two | tree
# --------------------------------------------------------------------
# N(one)           processing A
# N(two)           processing A
# N(tree)          processing A
# N(one)           processing B
# N(two)           processing B
# N(tree)          processing B

# %%
class N(Node):
    def process(self, rec):
        print('{:<16} processing {}'.format(self, rec))
        self.push(rec)
        
pipe = Pipeline(
    N('one') | N('two') | N('three')
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
#   one | two
#   two | three
# --------------------------------------------------------------------
# N(one)           processing A
# N(two)           processing A
# N(three)         processing A
# N(one)           processing B
# N(two)           processing B
# N(three)         processing B

# %% [markdown]
# # Broadcast to downstream nodes

# %%
pipe = Pipeline(
    N('one') | N('two') | [N('left'), N('right')]
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
#   one | two
#   two | [left, right]
# --------------------------------------------------------------------
# N(one)           processing A
# N(two)           processing A
# N(left)          processing A
# N(right)         processing A
# N(one)           processing B
# N(two)           processing B
# N(left)          processing B
# N(right)         processing B

# %% [markdown]
# # Merging branches

# %%
pipe = Pipeline(
    N('one') | N('two') | [N('left'), N('right')] | N('join')
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
#   one | two
#   two | [left, right]
#  left | join
# right | join
# --------------------------------------------------------------------
# N(one)           processing A
# N(two)           processing A
# N(left)          processing A
# N(join)          processing A
# N(right)         processing A
# N(join)          processing A
# N(one)           processing B
# N(two)           processing B
# N(left)          processing B
# N(join)          processing B
# N(right)         processing B
# N(join)          processing B

# %%
def router(item):
    return 'handle_A' if item == 'A' else 'handle_B'
pipe = Pipeline(
    N('one') | N('two') | [N('handle_A'), N('handle_B'), router] | N('join')
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
#        one | two
#        two | two.router
# two.router | [handle_A, handle_B]
#   handle_A | join
#   handle_B | join
# --------------------------------------------------------------------
# N(one)           processing A
# N(two)           processing A
# N(handle_A)      processing A
# N(join)          processing A
# N(one)           processing B
# N(two)           processing B
# N(handle_B)      processing B
# N(join)          processing B

# %%
class M(Node):
    def begin(self):
        print('{} beginning'.format(self.name))
        self.records = []
    
    def process(self, rec):
        print('{:<16} processing {}'.format(self, rec))
        self.records.append(rec)
        
    def end(self):
        for rec in self.records:
            self.push(rec)
        print('{} ending'.format(self.name))
        
pipe = Pipeline(
    M('one') | M('two')
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
# one | two
# --------------------------------------------------------------------
# one beginning
# two beginning
# N(one)           processing A
# N(one)           processing B
# N(two)           processing A
# N(two)           processing B
# one ending
# two ending

# %%
class M(Node):
    def begin(self):
        print('{} beginning'.format(self.name))
    
    def process(self, rec):
        print('{:<16} processing {}'.format(self, rec))
        self.push(rec)
        
    def end(self):
        print('{} ending'.format(self.name))

class CustomPipeline(Pipeline):
    def begin(self):
        print('pipeline beginning')

    def end(self):
        print('pipeline ending')
        
pipe = CustomPipeline(
    M('one') | M('two')
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.consume(list('AB'))
# Out:
# Pipeline
# --------------------------------------------------------------------
# one | two
# --------------------------------------------------------------------
# pipeline beginning
# one beginning
# two beginning
# N(one)           processing A
# N(two)           processing A
# N(one)           processing B
# N(two)           processing B
# one ending
# two ending
# pipeline ending

# %%
class P(Node):
    def process(self, rec):
        self.global_state.records_seen.add(rec)
        self.push(rec)

class CustomPipeline(Pipeline):
    def begin(self):
        self.global_state.records_seen = set()

    def end(self):
        return self.global_state.records_seen
        
pipe = CustomPipeline(
    P('one') | P('two')
)
print(pipe)
pipe.plot(display_noteook=True)

results = pipe.consume(list('AB'))
print(results)
# Out:
# Pipeline
# --------------------------------------------------------------------
# one | two
# --------------------------------------------------------------------
# set(['A', 'B'])

# %%
class P(Node):
    def process(self, rec):
        self.global_state.records_seen.add(rec)
        self.push(rec)

class CustomPipeline(Pipeline):
    def begin(self):
        self.global_state.records_seen = set()

    def end(self):
        return self.global_state.records_seen
        
pipe = CustomPipeline(
    P('one') | P('two')
)
print(pipe)
pipe.plot(display_noteook=True)

pipe.push('A')
pipe.push('B')
results = pipe.end()

print(results)
# Out:
# Pipeline
# --------------------------------------------------------------------
# one | two
# --------------------------------------------------------------------
# set(['A', 'B'])

# %%
def by_gender(item):
    return
def by_age(item):
    return

make_report = N('make_report')
p = Pipeline(
    N('read_data') | N('people')
    | [
        N('male') | [N('man') | N('sum_men'),
        N('boy') | N('sum_boys')
        ,by_age
      ], 
     N('female') | [N('woman') | N('sum_women'), N('girl') | N('sum_girls'), by_age],
        by_gender
        
    ]
    | make_report
)

sum_female = N('sum_female')
sum_male = N('sum_male')
sum_adult = N('sum_adult')
sum_child = N('sum_child')
p['male'].add_downstream(sum_male)
p['female'].add_downstream(sum_female)
p['woman'].add_downstream(sum_adult)
p['man'].add_downstream(sum_adult)
p['boy'].add_downstream(sum_child)
p['girl'].add_downstream(sum_child)
sum_male.add_downstream(make_report)
sum_female.add_downstream(make_report)

p.plot(display_noteook=True)

# %%
def by_gender(item):
    return
def by_age(item):
    return

make_report = N('make_report')
p = Pipeline(
    N('read_data') | N('people')
    | [
        N('male') 
        | [
            N('man') | N('sum_men'),
            N('boy') | N('sum_boys'),
            by_age
          ], 
        N('female') 
        | [
            N('woman') | N('sum_women'), 
            N('girl') | N('sum_girls'), 
            by_age
        ],
        by_gender
    ]
    | make_report
)

sum_female = N('sum_female')
sum_male = N('sum_male')
sum_adult = N('sum_adult')
sum_child = N('sum_child')
p['male'].add_downstream(sum_male)
p['female'].add_downstream(sum_female)
p['woman'].add_downstream(sum_adult)
p['man'].add_downstream(sum_adult)
p['boy'].add_downstream(sum_child)
p['girl'].add_downstream(sum_child)
sum_male.add_downstream(make_report)
sum_female.add_downstream(make_report)

p.plot(display_noteook=True)

# %%
def by_gender(item):
    return
def by_age(item):
    return

make_report = N('make_report')
sum_child = N('sum_child')
sum_adult = N('sum_adult')
p = Pipeline(
    N('read_data') | N('people')
    | 
      [
        N('male') | N('sum_male'),
        N('female') | N('sum_female'), 
        by_gender
      ]
    #| make_report
)
p.add_branch(
    'female',
    [
        N('woman') | [N('sum_women'), sum_adult],# | make_report, 
        N('girl') | [N('sum_girls'), sum_child], # | make_report,
        by_age
    ]
)
p.add_branch(
    'male',
    [
        N('men') | [N('sum_men'), sum_adult],# | make_report, 
        N('boy') | [N('sum_boys'), sum_child], # | make_report,
        by_age
    ]
)

# sum_female = N('sum_female')
# sum_male = N('sum_male')
# sum_adult = N('sum_adult')
# sum_child = N('sum_child')
# p['male'].add_downstream(sum_male)
# p['female'].add_downstream(sum_female)
# p['woman'].add_downstream(sum_adult)
# p['man'].add_downstream(sum_adult)
# p['boy'].add_downstream(sum_child)
# p['girl'].add_downstream(sum_child)
# sum_male.add_downstream(make_report)
# sum_female.add_downstream(make_report)

p.plot(display_noteook=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-cf6f5b0c2dc6> in <module>()
#      30         N('men') | [N('sum_men'), sum_adult],# | make_report,
#      31         N('boy') | [N('sum_boys'), sum_child], # | make_report,
# ---> 32         by_age
#      33     ]
#      34 )
#
# /Users/rob/rob/repos/consecution/consecution/pipeline.py in add_branch(self, node_names, branch)
#     170         router = self.top_node._get_router(branch)
#     171         self.top_node._connect_lefts_to_rights(
# --> 172             lefts, branch, lefts_are_slots=True, router=router
#     173         )
#     174
#
# /Users/rob/rob/repos/consecution/consecution/nodes.pyc in _connect_lefts_to_rights(self, lefts, rights, router, lefts_are_slots)
#      97             for right in slots_from_right:
#      98                 if router_node:
# ---> 99                     router_node.add_downstream(right)
#     100                 else:
#     101                     left.add_downstream(right)
#
# /Users/rob/rob/repos/consecution/consecution/nodes.pyc in add_downstream(self, other)
#     368
#     369         self._check_for_dups()
# --> 370         self._check_for_cycles()
#     371
#     372         self._pydot_edge_kwarg_list.append(
#
# /Users/rob/rob/repos/consecution/consecution/nodes.pyc in _check_for_cycles(self)
#     355         common_nodes = self_and_upstreams.intersection(downstreams)
#     356         if common_nodes:
# --> 357             raise ValueError('\n\nYour graph is not acyclic.  It has loops.')
#     358
#     359     def _validate_node(self, other):
#
# ValueError:
#
# Your graph is not acyclic.  It has loops.
